# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Importing IMDB Dataset

# %% [markdown]
# The dataset can be found here -> https://developer.imdb.com/non-commercial-datasets/
#
# For this analysis, I am using two datasets from IMDB
#
#     - Ratings dataset
#     - Basic title info dataset
#
# The goal is the match this dataset with my Netflix dataset and do a merge in order to expand my dataset for some cool analysis!

# %% [markdown]
# **title.basics.tsv.gz**
#
# - tconst (string) - alphanumeric unique identifier of the title
# - titleType (string) – the type/format of the title (e.g. movie, short, tvseries, tvepisode, video, etc)
# - primaryTitle (string) – the more popular title / the title used by the filmmakers on promotional materials at the point of release
# - originalTitle (string) - original title, in the original language
# - isAdult (boolean) - 0: non-adult title; 1: adult title
# - startYear (YYYY) – represents the release year of a title. In the case of TV Series, it is the series start year
# - endYear (YYYY) – TV Series end year. ‘\N’ for all other title types
# - runtimeMinutes – primary runtime of the title, in minutes
# - genres (string array) – includes up to three genres associated with the title

# %% [markdown]
# **title.ratings.tsv.gz**
#
# - tconst (string) - alphanumeric unique identifier of the title
# - averageRating – weighted average of all the individual user ratings
# - numVotes - number of votes the title has received

# %%
data_rating = pd.read_csv('/Users/pranavsukumaran/Desktop/netflix/project/data/data-2.tsv', sep='\t')

data_basic = pd.read_csv('/Users/pranavsukumaran/Desktop/netflix/project/data/data-3.tsv', sep='\t')
# Out:
# /var/folders/fk/b7dd25t91rq06z3l8zsn15r00000gn/T/ipykernel_23771/1094623698.py:3: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_basic = pd.read_csv('/Users/pranavsukumaran/Desktop/netflix/project/data/data-3.tsv', sep='\t')

# %%
data_basic.head()
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   isAdult startYear endYear runtimeMinutes                    genres
# 0       0      1894      \N              1         Documentary,Short
# 1       0      1892      \N              5           Animation,Short
# 2       0      1892      \N              4  Animation,Comedy,Romance
# 3       0      1892      \N             12           Animation,Short
# 4       0      1893      \N              1              Comedy,Short

# %%
data_rating.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      2029
# 1  tt0000002            5.7       272
# 2  tt0000003            6.5      1968
# 3  tt0000004            5.4       178
# 4  tt0000005            6.2      2732

# %%
final_data = data_basic[['tconst', 'titleType', 'primaryTitle', 'isAdult', 'startYear', 'runtimeMinutes', 'genres']]

final_data
# Out:
#              tconst  titleType               primaryTitle isAdult startYear  \
# 0         tt0000001      short                 Carmencita       0      1894
# 1         tt0000002      short     Le clown et ses chiens       0      1892
# 2         tt0000003      short             Pauvre Pierrot       0      1892
# 3         tt0000004      short                Un bon bock       0      1892
# 4         tt0000005      short           Blacksmith Scene       0      1893
# ...             ...        ...                        ...     ...       ...
# 10584562  tt9916848  tvEpisode              Episode #3.17       0      2009
# 10584563  tt9916850  tvEpisode              Episode #3.19       0      2010
# 10584564  tt9916852  tvEpisode              Episode #3.20       0      2010
# 10584565  tt9916856      short                   The Wind       0      2015
# 10584566  tt9916880  tvEpisode  Horrid Henry Knows It All       0      2014
#
#          runtimeMinutes                      genres
# 0                     1           Documentary,Short
# 1                     5             Animation,Short
# 2                     4    Animation,Comedy,Romance
# 3                    12             Animation,Short
# 4                     1                Comedy,Short
# ...                 ...                         ...
# 10584562             \N         Action,Drama,Family
# 10584563             \N         Action,Drama,Family
# 10584564             \N         Action,Drama,Family
# 10584565             27                       Short
# 10584566             10  Adventure,Animation,Comedy
#
# [10584567 rows x 7 columns]

# %%
merged_data = pd.merge(final_data, data_rating, on='tconst')

# %%
merged_data
# Out:
#             tconst  titleType                primaryTitle isAdult startYear  \
# 0        tt0000001      short                  Carmencita       0      1894
# 1        tt0000002      short      Le clown et ses chiens       0      1892
# 2        tt0000003      short              Pauvre Pierrot       0      1892
# 3        tt0000004      short                 Un bon bock       0      1892
# 4        tt0000005      short            Blacksmith Scene       0      1893
# ...            ...        ...                         ...     ...       ...
# 1406649  tt9916730      movie                      6 Gunn       0      2017
# 1406650  tt9916766  tvEpisode              Episode #10.15       0      2019
# 1406651  tt9916778  tvEpisode                      Escape       0      2019
# 1406652  tt9916840  tvEpisode  Horrid Henry's Comic Caper       0      2014
# 1406653  tt9916880  tvEpisode   Horrid Henry Knows It All       0      2014
#
#         runtimeMinutes                       genres  averageRating  numVotes
# 0                    1            Documentary,Short            5.7      2029
# 1                    5              Animation,Short            5.7       272
# 2                    4     Animation,Comedy,Romance            6.5      1968
# 3                   12              Animation,Short            5.4       178
# 4                    1                 Comedy,Short            6.2      2732
# ...                ...                          ...            ...       ...
# 1406649            116                        Drama            7.0        12
# 1406650             43  Family,Game-Show,Reality-TV            7.1        23
# 1406651             \N          Crime,Drama,Mystery            7.2        36
# 1406652             11   Adventure,Animation,Comedy            8.8         6
# 1406653             10   Adventure,Animation,Comedy            8.2         6
#
# [1406654 rows x 9 columns]

# %%
merged_data
# Out:
#             tconst  titleType                primaryTitle  \
# 0        tt0000001      short                  Carmencita
# 1        tt0000002      short      Le clown et ses chiens
# 2        tt0000003      short              Pauvre Pierrot
# 3        tt0000004      short                 Un bon bock
# 4        tt0000005      short            Blacksmith Scene
# ...            ...        ...                         ...
# 1406649  tt9916730      movie                      6 Gunn
# 1406650  tt9916766  tvEpisode              Episode #10.15
# 1406651  tt9916778  tvEpisode                      Escape
# 1406652  tt9916840  tvEpisode  Horrid Henry's Comic Caper
# 1406653  tt9916880  tvEpisode   Horrid Henry Knows It All
#
#                               genres  averageRating  numVotes
# 0                  Documentary,Short            5.7      2029
# 1                    Animation,Short            5.7       272
# 2           Animation,Comedy,Romance            6.5      1968
# 3                    Animation,Short            5.4       178
# 4                       Comedy,Short            6.2      2732
# ...                              ...            ...       ...
# 1406649                        Drama            7.0        12
# 1406650  Family,Game-Show,Reality-TV            7.1        23
# 1406651          Crime,Drama,Mystery            7.2        36
# 1406652   Adventure,Animation,Comedy            8.8         6
# 1406653   Adventure,Animation,Comedy            8.2         6
#
# [1406654 rows x 6 columns]

# %%
netflix_data = pd.read_csv("/Users/pranavsukumaran/Desktop/netflix/project/data/processed_data.csv")

# %%
merged_data['Title_lower'] = merged_data['primaryTitle'].str.lower()
netflix_data['Title_lower'] = netflix_data['Title'].str.lower()

# %%
imdb_max_votes = merged_data.loc[merged_data.groupby('Title_lower')['numVotes'].idxmax()]

# %%
imdb_max_votes
# Out:
#              tconst  titleType           primaryTitle isAdult startYear  \
# 941768    tt2386381   tvSeries                 !Next?       0      1994
# 867196    tt2071912  tvEpisode      !Que ve el Bisbe!       0      2011
# 786393    tt1699720      movie  !Women Art Revolution       0      2010
# 944625    tt2399574      short                      #       0      2012
# 1149114   tt4724630      video               # My Ass       1      2015
# ...             ...        ...                    ...     ...       ...
# 780813    tt1676214      short  Špansko the Continent       0      2009
# 734821   tt15392508      movie           Πέντε 5 Five       0      2023
# 122181    tt0180853      movie       Мужская компания       0      1992
# 874764   tt21030032   tvSeries           【Oshi No Ko】       0      2023
# 1346011   tt8331740   tvSeries               崖っぷちホテル！       0      2018
#
#         runtimeMinutes                   genres  averageRating  numVotes  \
# 941768              \N              Documentary            5.0        22
# 867196              \N                   Comedy            6.2        12
# 786393              83              Documentary            6.8       257
# 944625              15             Comedy,Short            3.1        12
# 1149114            143                    Adult            6.8         9
# ...                ...                      ...            ...       ...
# 780813              11      Action,Comedy,Drama            6.2        24
# 734821             135        Drama,History,War            7.1        27
# 122181              70         Action,Adventure            6.6        25
# 874764              24  Animation,Drama,Fantasy            8.4      8003
# 1346011             \N             Comedy,Drama            5.6        68
#
#                    Title_lower
# 941768                  !next?
# 867196       !que ve el bisbe!
# 786393   !women art revolution
# 944625                       #
# 1149114               # my ass
# ...                        ...
# 780813   špansko the continent
# 734821            πέντε 5 five
# 122181        мужская компания
# 874764            【oshi no ko】
# 1346011               崖っぷちホテル！
#
# [1042861 rows x 10 columns]

# %%
merged_data
# Out:
#             tconst  titleType                primaryTitle  \
# 0        tt0000001      short                  Carmencita
# 1        tt0000002      short      Le clown et ses chiens
# 2        tt0000003      short              Pauvre Pierrot
# 3        tt0000004      short                 Un bon bock
# 4        tt0000005      short            Blacksmith Scene
# ...            ...        ...                         ...
# 1406649  tt9916730      movie                      6 Gunn
# 1406650  tt9916766  tvEpisode              Episode #10.15
# 1406651  tt9916778  tvEpisode                      Escape
# 1406652  tt9916840  tvEpisode  Horrid Henry's Comic Caper
# 1406653  tt9916880  tvEpisode   Horrid Henry Knows It All
#
#                               genres  averageRating  numVotes  \
# 0                  Documentary,Short            5.7      2029
# 1                    Animation,Short            5.7       272
# 2           Animation,Comedy,Romance            6.5      1968
# 3                    Animation,Short            5.4       178
# 4                       Comedy,Short            6.2      2732
# ...                              ...            ...       ...
# 1406649                        Drama            7.0        12
# 1406650  Family,Game-Show,Reality-TV            7.1        23
# 1406651          Crime,Drama,Mystery            7.2        36
# 1406652   Adventure,Animation,Comedy            8.8         6
# 1406653   Adventure,Animation,Comedy            8.2         6
#
#                         Title_lower
# 0                        carmencita
# 1            le clown et ses chiens
# 2                    pauvre pierrot
# 3                       un bon bock
# 4                  blacksmith scene
# ...                             ...
# 1406649                      6 gunn
# 1406650              episode #10.15
# 1406651                      escape
# 1406652  horrid henry's comic caper
# 1406653   horrid henry knows it all
#
# [1406654 rows x 7 columns]

# %%
#final_merged_data = pd.merge(netflix_data, merged_data, left_on='Title', right_on='Title', how='left')

final_merge = imdb_max_votes.merge(netflix_data, on="Title_lower", how="inner")

# %%
final_merge
# Out:
#            tconst titleType           primaryTitle isAdult startYear  \
# 0      tt10311562  tvSeries               #BlackAF       0      2020
# 1      tt10311562  tvSeries               #BlackAF       0      2020
# 2      tt10311562  tvSeries               #BlackAF       0      2020
# 3      tt10311562  tvSeries               #BlackAF       0      2020
# 4      tt10311562  tvSeries               #BlackAF       0      2020
# ...           ...       ...                    ...     ...       ...
# 11345   tt7239256  tvSeries  Zumbo's Just Desserts       0      2016
# 11346   tt7239256  tvSeries  Zumbo's Just Desserts       0      2016
# 11347   tt7239256  tvSeries  Zumbo's Just Desserts       0      2016
# 11348   tt7239256  tvSeries  Zumbo's Just Desserts       0      2016
# 11349   tt7239256  tvSeries  Zumbo's Just Desserts       0      2016
#
#       runtimeMinutes                genres  averageRating  numVotes  \
# 0                 36                Comedy            6.8      5304
# 1                 36                Comedy            6.8      5304
# 2                 36                Comedy            6.8      5304
# 3                 36                Comedy            6.8      5304
# 4                 36                Comedy            6.8      5304
# ...              ...                   ...            ...       ...
# 11345             52  Game-Show,Reality-TV            6.9      2323
# 11346             52  Game-Show,Reality-TV            6.9      2323
# 11347             52  Game-Show,Reality-TV            6.9      2323
# 11348             52  Game-Show,Reality-TV            6.9      2323
# 11349             52  Game-Show,Reality-TV            6.9      2323
#
#                  Title_lower Profile Name  Duration                  Title  \
# 0                   #blackaf        Priya  0.428333               #blackAF
# 1                   #blackaf        Priya  0.523889               #blackAF
# 2                   #blackaf        Priya  0.108611               #blackAF
# 3                   #blackaf        Priya  0.181111               #blackAF
# 4                   #blackaf        Priya  0.286944               #blackAF
# ...                      ...          ...       ...                    ...
# 11345  zumbo's just desserts        Priya  0.243056  Zumbo's Just Desserts
# 11346  zumbo's just desserts        Priya  0.523056  Zumbo's Just Desserts
# 11347  zumbo's just desserts        Priya  0.125278  Zumbo's Just Desserts
# 11348  zumbo's just desserts        Priya  0.406667  Zumbo's Just Desserts
# 11349  zumbo's just desserts        Priya  0.523889  Zumbo's Just Desserts
#
#                    Country     Type  Hour  Day  Month  Year  \
# 0            TH (Thailand)  TV Show     9   28      9  2020
# 1            TH (Thailand)  TV Show     9   28      9  2020
# 2            TH (Thailand)  TV Show    16   27      9  2020
# 3            TH (Thailand)  TV Show    13   27      9  2020
# 4            TH (Thailand)  TV Show     7   27      9  2020
# ...                    ...      ...   ...  ...    ...   ...
# 11345  GB (United Kingdom)  TV Show    23   12      2  2019
# 11346  GB (United Kingdom)  TV Show    22   12      2  2019
# 11347  GB (United Kingdom)  TV Show    22   12      2  2019
# 11348  GB (United Kingdom)  TV Show    21   12      2  2019
# 11349  GB (United Kingdom)  TV Show    21   12      2  2019
#
#             Device Category
# 0      Apple Mobile Devices
# 1      Apple Mobile Devices
# 2      Apple Mobile Devices
# 3      Apple Mobile Devices
# 4      Apple Mobile Devices
# ...                     ...
# 11345          Web Browsers
# 11346          Web Browsers
# 11347          Web Browsers
# 11348          Web Browsers
# 11349          Web Browsers
#
# [11350 rows x 20 columns]

# %%
unique_titles_by_profile = final_merge.groupby('Profile Name')['primaryTitle'].nunique()
print(unique_titles_by_profile)
# Out:
# Profile Name
# Home      584
# Pranav    602
# Priya     225
# Name: primaryTitle, dtype: int64

# %%
final_merge.to_csv('merged_data.csv', index=False)
